# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from rt_visualizer import visualize_cams_rt

# %%
cams_dir = "/Users/mikhailli/Downloads/85761c22-60bd-4953-8629-4248950bd3c1/MESH/cameras"
mesh_path = "/Users/mikhailli/Downloads/85761c22-60bd-4953-8629-4248950bd3c1/MESH/mesh.ply"
out_mesh_path = "/Users/mikhailli/Downloads/test.ply"

visualize_cams_rt(cams_dir, mesh_path, out_mesh_path)
